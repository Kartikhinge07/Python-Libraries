# %%
import pandas as pd
import numpy as np

# %%
exam_data  = {'name': ['Sonu', 'Raja', 'Ketaki', 'Rupa', 'Radha', 'Reshma', 'Keshav', 'Narendra', 'Rani', 'Kittu'],
        'score': [12.5, 9, 16.5, np.nan, 9, 20, 14.5, np.nan, 8, 19],
        'attempts': [1, 3, 2, 3, 2, 3, 1, 1, 2, 1],
        'qualify': ['yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'yes']}
labels = ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j']
df=pd.DataFrame(exam_data,index=labels)
df
# Out:
#        name  score  attempts qualify
# a      Sonu   12.5         1     yes
# b      Raja    9.0         3      no
# c    Ketaki   16.5         2     yes
# d      Rupa    NaN         3      no
# e     Radha    9.0         2      no
# f    Reshma   20.0         3     yes
# g    Keshav   14.5         1     yes
# h  Narendra    NaN         1      no
# i      Rani    8.0         2      no
# j     Kittu   19.0         1     yes

# %%
df.describe()
# Out:
#            score   attempts
# count   8.000000  10.000000
# mean   13.562500   1.900000
# std     4.693746   0.875595
# min     8.000000   1.000000
# 25%     9.000000   1.000000
# 50%    13.500000   2.000000
# 75%    17.125000   2.750000
# max    20.000000   3.000000

# %%
df
# Out:
#        name  score  attempts qualify
# a      Sonu   12.5         1     yes
# b      Raja    9.0         3      no
# c    Ketaki   16.5         2     yes
# d      Rupa    NaN         3      no
# e     Radha    9.0         2      no
# f    Reshma   20.0         3     yes
# g    Keshav   14.5         1     yes
# h  Narendra    NaN         1      no
# i      Rani    8.0         2      no
# j     Kittu   19.0         1     yes

# %%
df[0:3]
# Out:
#      name  score  attempts qualify
# a    Sonu   12.5         1     yes
# b    Raja    9.0         3      no
# c  Ketaki   16.5         2     yes

# %%
df[["score","name"]]
# Out:
#    score      name
# a   12.5      Sonu
# b    9.0      Raja
# c   16.5    Ketaki
# d    NaN      Rupa
# e    9.0     Radha
# f   20.0    Reshma
# g   14.5    Keshav
# h    NaN  Narendra
# i    8.0      Rani
# j   19.0     Kittu

# %% [markdown]
# # que 5

# %%
d={'col1':[1,2,3],'col2':[4,5,6],'col3':[7,8,9]}
df1=pd.DataFrame(d)
df1
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6     9

# %%
df1.rename(columns={"col1":"a","col2":"b","col3":"c"},inplace = True )
df1
# Out:
#    a  b  c
# 0  1  4  7
# 1  2  5  8
# 2  3  6  9

# %%
df
# Out:
#        name  score  attempts qualify
# a      Sonu   12.5         1     yes
# b      Raja    9.0         3      no
# c    Ketaki   16.5         2     yes
# d      Rupa    NaN         3      no
# e     Radha    9.0         2      no
# f    Reshma   20.0         3     yes
# g    Keshav   14.5         1     yes
# h  Narendra    NaN         1      no
# i      Rani    8.0         2      no
# j     Kittu   19.0         1     yes

# %% [markdown]
# # que 6

# %%
df.loc['a':'j',["name","score"]]
# Out:
#        name  score
# a      Sonu   12.5
# b      Raja    9.0
# c    Ketaki   16.5
# d      Rupa    NaN
# e     Radha    9.0
# f    Reshma   20.0
# g    Keshav   14.5
# h  Narendra    NaN
# i      Rani    8.0
# j     Kittu   19.0

# %%
df.iloc[[1,3,5,6],[0,1]]
# Out:
#      name  score
# b    Raja    9.0
# d    Rupa    NaN
# f  Reshma   20.0
# g  Keshav   14.5

# %% [markdown]
# # que 7

# %%
df[df["attempts"]>2]
# Out:
#      name  score  attempts qualify
# b    Raja    9.0         3      no
# d    Rupa    NaN         3      no
# f  Reshma   20.0         3     yes

# %% [markdown]
# # que 8

# %%
df.shape[0]  #rows count
# Out:
# 10

# %%
df.shape[1]  #column count
# Out:
# 4

# %% [markdown]
# # que 9

# %%
df[df['score'].isnull()]
# Out:
#        name  score  attempts qualify
# d      Rupa    NaN         3      no
# h  Narendra    NaN         1      no

# %%
df
# Out:
#        name  score  attempts qualify
# a      Sonu   12.5         1     yes
# b      Raja    9.0         3      no
# c    Ketaki   16.5         2     yes
# d      Rupa    NaN         3      no
# e     Radha    9.0         2      no
# f    Reshma   20.0         3     yes
# g    Keshav   14.5         1     yes
# h  Narendra    NaN         1      no
# i      Rani    8.0         2      no
# j     Kittu   19.0         1     yes

# %% [markdown]
# # que 10

# %%
df[(df["score"]>=15) & (df['score']<=20) ]
# Out:
#      name  score  attempts qualify
# c  Ketaki   16.5         2     yes
# f  Reshma   20.0         3     yes
# j   Kittu   19.0         1     yes

# %% [markdown]
# # que 11

# %%
df[(df["attempts"]<2) & (df['score']>15) ]
# Out:
#     name  score  attempts qualify
# j  Kittu   19.0         1     yes

# %% [markdown]
# # que 12

# %%
df["attempts"].sum()
# Out:
# 19

# %% [markdown]
# # que 13

# %%
df['score'].mean()
# Out:
# 13.5625

# %% [markdown]
# # que 14

# %%
df.loc['k']=["Rakesh",16,2,'no']
df
# Out:
#        name  score  attempts qualify
# a      Sonu   12.5         1     yes
# b      Raja    9.0         3      no
# c    Ketaki   16.5         2     yes
# d      Rupa    NaN         3      no
# e     Radha    9.0         2      no
# f    Reshma   20.0         3     yes
# g    Keshav   14.5         1     yes
# h  Narendra    NaN         1      no
# i      Rani    8.0         2      no
# j     Kittu   19.0         1     yes
# k    Rakesh   16.0         2      no

# %% [markdown]
# ## Que 15

# %%
df.sort_values(['name','score'],ascending=[False,True])
df
# Out:
#        name  score  attempts qualify
# a      Sonu   12.5         1     yes
# b      Raja    9.0         3      no
# c    Ketaki   16.5         2     yes
# d      Rupa    NaN         3      no
# e     Radha    9.0         2      no
# f    Reshma   20.0         3     yes
# g    Keshav   14.5         1     yes
# h  Narendra    NaN         1      no
# i      Rani    8.0         2      no
# j     Kittu   19.0         1     yes
# k    Rakesh   16.0         2      no

# %% [markdown]
# ## ques 16

# %%
df["qualify"].replace({'yes': True,'no':False})
# Out:
# a     True
# b    False
# c     True
# d    False
# e    False
# f     True
# g     True
# h    False
# i    False
# j     True
# k    False
# Name: qualify, dtype: bool

# %%
print(df)
# Out:
#        name  score  attempts qualify
# a      Sonu   12.5         1     yes
# b      Raja    9.0         3      no
# c    Ketaki   16.5         2     yes
# d      Rupa    NaN         3      no
# e     Radha    9.0         2      no
# f    Reshma   20.0         3     yes
# g    Keshav   14.5         1     yes
# h  Narendra    NaN         1      no
# i      Rani    8.0         2      no
# j     Kittu   19.0         1     yes
# k    Rakesh   16.0         2      no

# %% [markdown]
# ## ques 17

# %%
df.drop(['attempts'],axis=1)   #df.drop(columns=['attempts'])
# Out:
#        name  score qualify
# a      Sonu   12.5     yes
# b      Raja    9.0      no
# c    Ketaki   16.5     yes
# d      Rupa    NaN      no
# e     Radha    9.0      no
# f    Reshma   20.0     yes
# g    Keshav   14.5     yes
# h  Narendra    NaN      no
# i      Rani    8.0      no
# j     Kittu   19.0     yes
# k    Rakesh   16.0      no

# %% [markdown]
# ##  ques 18

# %%
df['class']='new values'
df
# Out:
#        name  score  attempts qualify       class
# a      Sonu   12.5         1     yes  new values
# b      Raja    9.0         3      no  new values
# c    Ketaki   16.5         2     yes  new values
# d      Rupa    NaN         3      no  new values
# e     Radha    9.0         2      no  new values
# f    Reshma   20.0         3     yes  new values
# g    Keshav   14.5         1     yes  new values
# h  Narendra    NaN         1      no  new values
# i      Rani    8.0         2      no  new values
# j     Kittu   19.0         1     yes  new values
# k    Rakesh   16.0         2      no  new values
