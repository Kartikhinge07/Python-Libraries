# %%
#pip install pillow

# %%
import PIL as p
from PIL import Image

# %%
img=Image.open(r"C:\Users\KARTIK\Desktop\images.jpeg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
img.show()

# %%
display(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168>

# %%
img.mode # image mode
# Out:
# 'RGB'

# %%
img.filename #name of file wiht path
# Out:
# 'C:\\Users\\KARTIK\\Desktop\\images.jpeg'

# %%
img.format #type  of image
# Out:
# 'JPEG'

# %%
img.size
# Out:
# (300, 168)

# %% [markdown]
# # methods
# ### rotate()
#
# ### resize()
#
# ### reduce()
#
# ### thumbnail()
#
# ### save()

# %%
img.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
img.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
img2=img.rotate(180)
img2.save(r"C:\Users\KARTIK\Desktop\images.jpeg")
display(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
img.reduce((10,10))
# Out:
# <PIL.Image.Image image mode=RGB size=30x17>

# %%
img.save()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 img.save()
#
# TypeError: Image.save() missing 1 required positional argument: 'fp'
